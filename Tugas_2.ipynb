# %% [markdown]
# # Tugas 2
# ## List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
# 1. Tampilkan Angka Ganjil dari ke 50 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut
#
# Berikut Kodenya:

# %%
#tugas 2 wahyu; saved 2018-10-22 23:26:53
import random

# GENERATE RANDOM
banyakNilai=250
nilaiTugas=[]
for i in range(banyakNilai):
    nilaiTugas.append(random.randrange(1,100,1))

nilaiGanjil=[]#untuk nilai gangil
besarDari70=[]#untuk nilai > 70
nilaiTugasKuadrat=[]#untuk std deviasi

for i in nilaiTugas:
    # BILANGAN GANJIL
    if nilaiTugas[i] % 2 != 0:
        nilaiGanjil.append(nilaiTugas[i])
    # NILAI > 70
    if nilaiTugas[i]>70:
        besarDari70.append(nilaiTugas[i])
    nilaiTugasKuadrat.append(pow(nilaiTugas[i],2))#untuk std deviasi

# STANDAR DEVIASI (manual)
jumlahNilaiTugas=sum(nilaiTugas)
jumlahNilaiTugasKuadrat=sum(nilaiTugasKuadrat)
kuadratJumlahNilaiTugas=pow(jumlahNilaiTugas,2)
varian=((banyakNilai*jumlahNilaiTugasKuadrat)-kuadratJumlahNilaiTugas)/(banyakNilai*(banyakNilai-1))

# MAKSIMUM
nilaiMaksimum=max(nilaiTugas)

# MINIMUM
nilaiMinimum=min(nilaiTugas)

# MODUS
kemunculan=[]
for i in nilaiTugas:
    jumlahMuncul = nilaiTugas.count(i)
    nilai = (jumlahMuncul,i)
    if nilai not in kemunculan:
        kemunculan.append(nilai)
kemunculan.sort(reverse=True)

print("\n Banyak Nilai =",banyakNilai,"\n")
print("Nilai Random:\n",nilaiTugas,"\n")
print("1. Nilai Ganjil Ada",len(nilaiGanjil),"Records:\n",nilaiGanjil,"\n")
print("2. Nilai > 70 Ada",len(besarDari70),"Records:\n",besarDari70,"\n")
print("3. Standar Deviasi:")
print("# Nilai Tugas Kuadrat =",nilaiTugasKuadrat)
print("# Jumlah Nilai Tugas =",jumlahNilaiTugas)
print("# Jumlah dari Nilai Tugas Kuadrat =",jumlahNilaiTugasKuadrat)
print("# Kuadrat dari Jumlah Nilai Tugas =",kuadratJumlahNilaiTugas)
print("# Varian = ((Banyak Nilai * Jumlah dari Nilai Tugas Kuadrat) - Kuadrat dari Jumlah Nilai Tugas ) / (Banyak Nilai * (Banyak Nilai - 1))")
print("# Varian = ((",banyakNilai,"*",jumlahNilaiTugasKuadrat,") -",kuadratJumlahNilaiTugas,") / (",banyakNilai,"* (",banyakNilai,"- 1))")
print("# Varian =",varian)
print("# Standar Deviasi = Akar Kuadrat dari Varian")
print("# Standar Deviasi =",pow(varian,0.5),"\n")
print("4. Nilai Maksimum :",nilaiMaksimum,"\n")
print("5. Nilai Minimum :",nilaiMinimum,"\n")
if kemunculan[0][0]>kemunculan[1][0]:
    print("6. Nilai Modus:", kemunculan[0][1], ", Muncul", kemunculan[0][0], "Kali")
else:
    print("6. Nilai Modus: Tidak Tunggal")
print("\n",kemunculan)
# Out:
#  Banyak Nilai = 250
#
# Nilai Random:
 961, 1764, 5476, 9409, 3364, 1225, 9409, 961, 3721, 5476, 4761, 4761, 784, 3025, 529, 144, 4, 2209, 4096, 729, 5184, 9216, 1764, 361, 361, 144, 7921, 225, 6241, 4900, 9604, 5625, 1225, 6724, 1024, 2209, 4624, 1764, 4624, 8100, 361, 784, 2209, 289, 6561, 196, 6241, 6241, 3364, 7056, 5776, 3025, 5929, 3364, 676, 2601, 3364, 784, 3364, 9216, 6724, 7921, 3721, 5929, 2704, 7921, 1024, 8649, 484, 4761, 3364, 25, 289, 3364, 4356, 9409, 5929, 2601, 9604, 6561, 2704, 7056, 3600, 3600, 3969, 2601, 225, 6561, 9801, 6889, 484, 961, 9604, 9604, 3025, 2601, 4096, 3600, 4096, 5184, 3136, 7744, 7744, 2025, 225, 8100, 4761, 8100, 7744, 5476, 1225, 1225, 961, 9801, 729, 3025, 9604, 729, 6241, 9409, 225, 3025, 1681, 2209, 5476, 4, 729, 1681, 3136, 9409, 4761, 3136, 484, 729, 25, 2025, 8100, 1681, 1764, 441, 1936, 3136, 7921, 8100, 2209, 3600, 225, 225, 1444, 3249, 8649, 3600, 4096, 2601, 3364, 4096, 100, 361, 2704, 7921, 100, 1681, 225, 36, 1024, 5625, 7056, 2704, 9409, 5476, 4624, 9604, 4624, 961, 1444, 100, 9409, 3600, 6241, 361, 8649, 9409, 6889, 729, 9801, 1024, 5929, 6561, 3364, 1024, 1936, 4, 4900]
# # Jumlah Nilai Tugas = 12538
# # Jumlah dari Nilai Tugas Kuadrat = 1005809
# # Kuadrat dari Jumlah Nilai Tugas = 157201444
# # Varian = ((Banyak Nilai * Jumlah dari Nilai Tugas Kuadrat) - Kuadrat dari Jumlah Nilai Tugas ) / (Banyak Nilai * (Banyak Nilai - 1))
# # Varian = (( 250 * 1005809 ) - 157201444 ) / ( 250 * ( 250 - 1))
# # Varian = 1514.069172690763
# # Standar Deviasi = Akar Kuadrat dari Varian
# # Standar Deviasi = 38.91104178367322
#
# 4. Nilai Maksimum : 99
#
# 5. Nilai Minimum : 1
#
# 6. Nilai Modus: 15 , Muncul 7 Kali
#
#  [(7, 15), (6, 98), (6, 60), (6, 58), (5, 51), (5, 47), (5, 35), (5, 31), (5, 12), (4, 87), (4, 83), (4, 82), (4, 79), (4, 78), (4, 75), (4, 74), (4, 70), (4, 69), (4, 50), (4, 42), (4, 37), (4, 21), (4, 20), (4, 7), (3, 95), (3, 93), (3, 90), (3, 89), (3, 88), (3, 76), (3, 68), (3, 61), (3, 57), (3, 55), (3, 44), (3, 40), (3, 32), (3, 30), (3, 28), (3, 27), (3, 23), (3, 19), (3, 17), (3, 13), (3, 6), (3, 5), (3, 4), (2, 99), (2, 97), (2, 96), (2, 94), (2, 91), (2, 84), (2, 81), (2, 77), (2, 72), (2, 71), (2, 66), (2, 64), (2, 63), (2, 53), (2, 52), (2, 49), (2, 45), (2, 41), (2, 39), (2, 38), (2, 26), (2, 18), (2, 16), (2, 14), (2, 11), (2, 2), (2, 1), (1, 85), (1, 80), (1, 73), (1, 65), (1, 56), (1, 48), (1, 46), (1, 36), (1, 34), (1, 33), (1, 29), (1, 24), (1, 22), (1, 10), (1, 9), (1, 8), (1, 3)]

# %% [markdown]
# ## Word Count
# Diberikan sebuah paragraf, hitunglah banyak kemunculan masing-masing kata.
# Contoh : "Presiden pagi ini melakukan kunjungan ke Jogja"
#
# - Presiden: 1
# - pagi: 1
# - ini: 1
# - melakukan: 1
# - kunjungan: 1
# - ke: 1
# - Jogja: 1
#
# hints: Gunakan Dictionary dalam menyimpan word count. Gunakan kata sebagai key, dan jumlah kemunculan sebagai value
#
# Berikut Kodenya:

# %%
paragraf="Barcelona berhasil merebut posisi puncak klasemen La Liga Spanyol seusai menang 4-2 atas Sevilla pada pertandingan pekan kesembilan di Stadion Camp Nou, Sabtu (20/10/2018) atau Minggu dini hari WIB. Barcelona membuka keunggulan pada menit ke-2 melalui gol yang dicetak oleh Philippe Coutinho. Lionel Messi menggandakan keunggulan Barcelona, 10 menit berselang.  Namun, nahas bagi Barcelona, karena Messi harus ditarik keluar pada menit ke-26 setelah mengalami cedera. Tanpa Messi, skor 2-0 bertahan hingga babak pertama berakhir."
#fungsi replace keroyokan
def replace_all(text,dic):
    for i, j in dic.items():
        text = text.replace(i,j)#replace
    return text
dicRep={".":"",",":"","-":"","/":"","(":"",")":""}#dictionary bahan replace
kata=replace_all(paragraf.lower(),dicRep).split()
print("Cleaned Token:\n",kata,"\n")

kemunculan={}
for k in kata:
    if k in kemunculan:
        kemunculan[k]+=1
    else:
        kemunculan[k]=1
print("Word Count:\n")
for k,l in kemunculan.items():
    print(k, "->", l)
# Out:
# Cleaned Token:
#  ['barcelona', 'berhasil', 'merebut', 'posisi', 'puncak', 'klasemen', 'la', 'liga', 'spanyol', 'seusai', 'menang', '42', 'atas', 'sevilla', 'pada', 'pertandingan', 'pekan', 'kesembilan', 'di', 'stadion', 'camp', 'nou', 'sabtu', '20102018', 'atau', 'minggu', 'dini', 'hari', 'wib', 'barcelona', 'membuka', 'keunggulan', 'pada', 'menit', 'ke2', 'melalui', 'gol', 'yang', 'dicetak', 'oleh', 'philippe', 'coutinho', 'lionel', 'messi', 'menggandakan', 'keunggulan', 'barcelona', '10', 'menit', 'berselang', 'namun', 'nahas', 'bagi', 'barcelona', 'karena', 'messi', 'harus', 'ditarik', 'keluar', 'pada', 'menit', 'ke26', 'setelah', 'mengalami', 'cedera', 'tanpa', 'messi', 'skor', '20', 'bertahan', 'hingga', 'babak', 'pertama', 'berakhir']
#
# Word Count:
#
# barcelona -> 4
# berhasil -> 1
# merebut -> 1
# posisi -> 1
# puncak -> 1
# klasemen -> 1
# la -> 1
# liga -> 1
# spanyol -> 1
# seusai -> 1
# menang -> 1
# 42 -> 1
# atas -> 1
# sevilla -> 1
# pada -> 3
# pertandingan -> 1
# pekan -> 1
# kesembilan -> 1
# di -> 1
# stadion -> 1
# camp -> 1
# nou -> 1
# sabtu -> 1
# 20102018 -> 1
# atau -> 1
# minggu -> 1
# dini -> 1
# hari -> 1
# wib -> 1
# membuka -> 1
# keunggulan -> 2
# menit -> 3
# ke2 -> 1
# melalui -> 1
# gol -> 1
# yang -> 1
# dicetak -> 1
# oleh -> 1
# philippe -> 1
# coutinho -> 1
# lionel -> 1
# messi -> 3
# menggandakan -> 1
# 10 -> 1
# berselang -> 1
# namun -> 1
# nahas -> 1
# bagi -> 1
# karena -> 1
# harus -> 1
# ditarik -> 1
# keluar -> 1
# ke26 -> 1
# setelah -> 1
# mengalami -> 1
# cedera -> 1
# tanpa -> 1
# skor -> 1
# 20 -> 1
# bertahan -> 1
# hingga -> 1
# babak -> 1
# pertama -> 1
# berakhir -> 1
