# %% [markdown]
# # Tugas 5
# Adapun database yang digunakan adalah database contoh yang sudah diberikan pengajar.
#
# ### One to many relationship
# 1. Report the account representative for each customer.
# 2. Report total payments for Atelier graphique.
# 3. Report the total payments by date
# 4. Report the products that have not been sold.
# 5. List the amount paid by each customer.
# 6. How many orders have been placed by Herkku Gifts?
# 7. Who are the employees in Boston?
# 8. Report those payments greater than \$100,000. Sort the report so the customer who made the highest payment appears first.
# 9. List the value of 'On Hold' orders.
# 10. Report the number of orders 'On Hold' for each customer.
#
# ### Many to many relationship
# 1. List products sold by order date.
# 2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck.
# 3. List the names of customers and their corresponding order number where a particular order from that customer has a value greater than $25,000?
# 4. Are there any products that appear on all orders?
# 5. List the names of products sold at less than 80% of the MSRP.
# 6. Reports those products that have been sold with a markup of 100% or more (i.e.,  the priceEach is at least twice the buyPrice)
# 7. List the products ordered on a Monday.
# 8. What is the quantity on hand for products listed on 'On Hold' orders?

# %%
#koneksi database
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')
#fungsi untuk query dijalankan ditampilkan
def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## 1 to Many

# %%
#1. Report the account representative for each customer
run("""SELECT customers.customerName,
    CONCAT(employees.firstName,' ',employees.lastName) AS accRepresentative
FROM customers
LEFT JOIN employees ON customers.salesRepEmployeeNumber = employees.employeeNumber
ORDER BY employees.firstName DESC
""")
# Out:
#                        customerName accRepresentative
# 0                  FunGiftIdeas.com   Steve Patterson
# 1             Diecast Classics Inc.   Steve Patterson
# 2      Online Diecast Creations Co.   Steve Patterson
# 3              Marta's Replicas Co.   Steve Patterson
# 4           Auto-Moto Classics Inc.   Steve Patterson
# 5                 Gifts4AllAges.com   Steve Patterson
# 6     Extreme Desk Decorations, Ltd       Peter Marsh
# 7        Down Under Souveniers, Inc       Peter Marsh
# 8                 Kelly's Gift Shop       Peter Marsh
# 9                  Handji Gifts& Co       Peter Marsh
# 10                  GiftsForHim.com       Peter Marsh
# 11         Danish Wholesale Imports   Pamela Castillo
# 12              L'ordine Souveniers   Pamela Castillo
# 13               Amica Models & Co.   Pamela Castillo
# 14                       Petit Auto   Pamela Castillo
# 15             Heintze Collectables   Pamela Castillo
# ...

# %%
#2. Report total payments for Atelier graphique
run("""SELECT SUM(payments.amount) AS total
FROM payments
INNER JOIN customers ON payments.customerNumber = customers.customerNumber
WHERE customers.customerName = 'Atelier graphique'
""")
# Out:
#       total
# 0  22314.36

# %%
#3. Report the total payments by date
run("SELECT paymentDate,SUM(amount) AS total FROM payments GROUP BY paymentDate ORDER BY total DESC")
# Out:
#     paymentDate      total
# 0    2004-12-31  168374.40
# 1    2003-12-26  165008.14
# 2    2003-11-24  121700.49
# 3    2005-03-18  120166.58
# 4    2003-12-09  117002.59
# 5    2003-08-15  111654.40
# 6    2004-11-02  109385.00
# 7    2003-11-18  106177.78
# 8    2004-11-06  103574.43
# 9    2005-03-05  101244.59
# 10   2004-03-15   99373.13
# 11   2003-12-05   93564.95
# 12   2004-11-16   91188.64
# 13   2004-11-27   91169.70
# 14   2004-06-21   86221.60
# 15   2003-11-03   85559.12
# 16   2004-08-28   85410.87
# 17   2003-12-03   85024.46
# 18   2005-04-16   83598.04
# 19   2004-12-15   82261.22
# 20   2003-11-22   76602.15
# 21   2005-05-19   75396.26
# 22   2004-09-05   75394.20
# 23   2003-12-10   75217.73
# 24   2005-05-23   75020.13
# 25   2004-12-08   73407.89
# 26   2003-09-28   71551.82
# 27   2005-03-25   65071.26
# 28   2003-12-07   64080.87
# 29   2004-09-07   63357.13
# ..          ...        ...
# 202  2004-07-28    9415.13
# 203  2005-01-18    8307.28
# ...

# %%
#4. Report the products that have not been sold
run("""SELECT products.productCode,products.productName,products.productLine,
    products.quantityInStock,products.buyPrice,products.MSRP
FROM products
LEFT JOIN orderdetails ON orderdetails.productCode = products.productCode
WHERE orderdetails.orderNumber IS NULL
""")
# Out:
#   productCode        productName   productLine  quantityInStock  buyPrice  \
# 0    S18_3233  1985 Toyota Supra  Classic Cars             7733     57.01
#
#      MSRP
# 0  107.57

# %%
#5. List the amount paid by each customer
run("""SELECT customers.customerNumber,customers.customerName,Sum(payments.amount) AS totalAmount
FROM customers
INNER JOIN payments ON payments.customerNumber = customers.customerNumber
GROUP BY customers.customerNumber
ORDER BY totalAmount DESC
""")
# Out:
#     customerNumber                        customerName  totalAmount
# 0              141              Euro+ Shopping Channel    715738.98
# 1              124        Mini Gifts Distributors Ltd.    584188.24
# 2              114          Australian Collectors, Co.    180585.07
# 3              151                  Muscle Machine Inc    177913.95
# 4              148             Dragon Souveniers, Ltd.    156251.03
# 5              323          Down Under Souveniers, Inc    154622.08
# 6              187                      AV Stores, Co.    148410.09
# 7              276             Anna's Decorations, Ltd    137034.22
# 8              321            Corporate Gift Ideas Co.    132340.78
# 9              146              Saveley & Henriot, Co.    130305.35
# 10             278                       Rovelli Gifts    127529.69
# 11             353                  Reims Collectables    126983.19
# 12             119                   La Rochelle Gifts    116949.68
# ...

# %%
#6. How many orders have been placed by Herkku Gifts?
run("""SELECT COUNT(orders.orderNumber) AS jumlah
FROM orders
INNER JOIN customers ON orders.customerNumber = customers.customerNumber
WHERE customers.customerName LIKE 'herkku%'
""")
# Out:
#    jumlah
# 0       3

# %%
#7. Who are the employees in Boston?
run("""SELECT employees.employeeNumber,
    CONCAT(employees.firstName,' ',employees.lastName) AS employeeName
FROM employees
INNER JOIN offices ON employees.officeCode = offices.officeCode
WHERE offices.city = 'boston'
""")
# Out:
#    employeeNumber     employeeName
# 0            1188   Julie Firrelli
# 1            1216  Steve Patterson

# %%
#8. Report those payments greater than $100,000. Sort the report so the customer who made the highest payment appears first
run("""SELECT customers.customerNumber,customers.customerName,Sum(payments.amount) AS totalAmount
FROM customers
INNER JOIN payments ON payments.customerNumber = customers.customerNumber
GROUP BY customers.customerNumber
HAVING totalAmount > '100000'
ORDER BY totalAmount DESC
""")
# Out:
#     customerNumber                  customerName  totalAmount
# 0              141        Euro+ Shopping Channel    715738.98
# 1              124  Mini Gifts Distributors Ltd.    584188.24
# 2              114    Australian Collectors, Co.    180585.07
# 3              151            Muscle Machine Inc    177913.95
# 4              148       Dragon Souveniers, Ltd.    156251.03
# 5              323    Down Under Souveniers, Inc    154622.08
# 6              187                AV Stores, Co.    148410.09
# 7              276       Anna's Decorations, Ltd    137034.22
# 8              321      Corporate Gift Ideas Co.    132340.78
# 9              146        Saveley & Henriot, Co.    130305.35
# 10             278                 Rovelli Gifts    127529.69
# 11             353            Reims Collectables    126983.19
# 12             119             La Rochelle Gifts    116949.68
# 13             363  Online Diecast Creations Co.    116449.29
# ...

# %%
#9. List the value of 'On Hold' orders
run("""SELECT orderdetails.orderNumber,
    SUM(orderdetails.quantityOrdered*orderdetails.priceEach) AS nilai
FROM orderdetails
INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
WHERE orders.`status` = 'On Hold'
GROUP BY orderdetails.orderNumber
ORDER BY nilai DESC
""")
# Out:
#    orderNumber     nilai
# 0        10407  52229.55
# 1        10414  50806.85
# 2        10401  43525.04
# 3        10334  23014.17

# %%
#10. Report the number of orders 'On Hold' for each customer
run("""SELECT customers.customerName,
    Sum(orderdetails.quantityOrdered) AS jumlahPieceOrder
FROM orderdetails
INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
INNER JOIN customers ON orders.customerNumber = customers.customerNumber
WHERE orders.`status` = 'On Hold'
GROUP BY customers.customerName
""")
# Out:
#                 customerName  jumlahPieceOrder
# 0          Gifts4AllAges.com             609.0
# 1    Tekni Collectables Inc.             597.0
# 2  The Sharp Gifts Warehouse             571.0
# 3   Volvo Model Replicas, Co             217.0

# %% [markdown]
# ## Many to Many

# %%
#1. List products sold by order date
run("""SELECT products.productCode,products.productName,orders.orderDate
FROM products
INNER JOIN orderdetails ON orderdetails.productCode = products.productCode
INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
WHERE orders.`status` NOT IN ('On Hold', 'Disputed')
GROUP BY products.productCode
ORDER BY orders.orderDate ASC
""")
# Out:
#     productCode                                  productName   orderDate
# 0      S18_2248                           1911 Ford Town Car  2003-01-06
# 1      S18_4409          1932 Alfa Romeo 8C2300 Spider Sport  2003-01-06
# 2      S18_1749                     1917 Grand Touring Sedan  2003-01-06
# 3      S24_3969             1936 Mercedes Benz 500k Roadster  2003-01-06
# 4      S18_2795                       1928 Mercedes-Benz SSK  2003-01-09
# 5      S24_1937                  1939 Chevrolet Deluxe Coupe  2003-01-09
# 6      S24_2022    1938 Cadillac V-16 Presidential Limousine  2003-01-09
# 7      S18_2325                    1932 Model A Ford J-Coupe  2003-01-09
# 8      S18_1342                         1937 Lincoln Berline  2003-01-10
# 9      S18_1367     1936 Mercedes-Benz 500K Special Roadster  2003-01-10
# 10     S18_2949                  1913 Ford Model T Speedster  2003-01-29
# 11     S18_3320                     1917 Maxwell Touring Car  2003-01-29
# ...

# %%
#2. List the order dates in descending order for orders for the 1940 Ford Pickup Truck
run("""SELECT orders.orderNumber,orders.orderDate
FROM orders
INNER JOIN orderdetails ON orderdetails.orderNumber = orders.orderNumber
INNER JOIN products ON orderdetails.productCode = products.productCode
WHERE products.productName = '1940 Ford Pickup Truck'
ORDER BY orders.orderDate DESC
""")
# Out:
#     orderNumber   orderDate
# 0         10424  2005-05-31
# 1         10411  2005-05-01
# 2         10391  2005-03-09
# 3         10381  2005-02-17
# 4         10370  2005-01-20
# 5         10357  2004-12-10
# 6         10347  2004-11-29
# 7         10333  2004-11-18
# 8         10322  2004-11-04
# 9         10312  2004-10-21
# 10        10304  2004-10-11
# 11        10291  2004-09-08
# 12        10280  2004-08-17
# 13        10270  2004-07-19
# 14        10258  2004-06-15
# 15        10245  2004-05-04
# 16        10228  2004-03-10
# 17        10215  2004-01-29
# 18        10206  2003-12-05
# 19        10194  2003-11-25
# 20        10183  2003-11-13
# 21        10174  2003-11-06
# 22        10164  2003-10-21
# 23        10150  2003-09-19
# 24        10140  2003-07-24
# 25        10126  2003-05-28
# 26        10113  2003-03-26
# 27        10103  2003-01-29

# %%
#3. List the names of customers and their corresponding order number where
#   a particular order from that customer has a value greater than $25,000?
run("""SELECT customers.customerName,orders.orderNumber,
    SUM(orderdetails.quantityOrdered*orderdetails.priceEach) AS nilai
FROM customers
INNER JOIN orders ON orders.customerNumber = customers.customerNumber
INNER JOIN orderdetails ON orderdetails.orderNumber = orders.orderNumber
GROUP BY orders.orderNumber
HAVING nilai>'25000'
ORDER BY customers.customerName ASC
""")
# Out:
#                            customerName  orderNumber     nilai
# 0                          Alpha Cognac        10178  33818.34
# 1                    Amica Models & Co.        10280  48298.99
# 2                    Amica Models & Co.        10293  33924.24
# 3               Anna's Decorations, Ltd        10169  38547.19
# 4               Anna's Decorations, Ltd        10370  27083.78
# 5               Anna's Decorations, Ltd        10391  29848.52
# 6               Anna's Decorations, Ltd        10148  41554.73
# 7          Australian Collectables, Ltd        10193  35505.63
# 8            Australian Collectors, Co.        10342  40265.60
# 9            Australian Collectors, Co.        10120  45864.03
# 10           Australian Collectors, Co.        10347  41995.62
# 11           Australian Collectors, Co.        10223  44894.74
# 12                 Auto Associés & Cie.        10304  53116.99
# 13                    Auto Canal+ Petit        10252  25080.96
# ...

# %%
#4. Are there any products that appear on all orders?
print("Dicari produk yang orderNumbernya 'NULL', kalau ada artinya 'Tidak Ada Satupun Produk yang Muncul di Setiap Order'")
run("""SELECT products.productCode
FROM products
LEFT JOIN orderdetails ON orderdetails.productCode = products.productCode
WHERE orderdetails.orderNumber IS NULL
""")
# Out:
# Dicari produk yang orderNumbernya 'NULL', kalau ada artinya 'Tidak Ada Satupun Produk yang Muncul di Setiap Order'
#   productCode
# 0    S18_3233

# %%
#5. List the names of products sold at less than 80% of the MSRP
run("""SELECT products.productName,products.MSRP,
    orderdetails.priceEach,(products.MSRP*80/100) AS `80markup`
FROM products
INNER JOIN orderdetails ON orderdetails.productCode = products.productCode
HAVING orderdetails.priceEach<`80markup`
""")
# Out:
#                                     productName    MSRP  priceEach  80markup
# 0                         1996 Moto Guzzi 1100i  118.94      95.15    95.152
# 1                               1993 Mazda RX-7  141.54     113.23   113.232
# 2                          1937 Lincoln Berline  102.74      82.19    82.192
# 3                         1965 Aston Martin DB5  124.44      99.55    99.552
# 4                         1965 Aston Martin DB5  124.44      99.55    99.552
# 5                   1980s Black Hawk Helicopter  157.69     126.15   126.152
# 6                   1980s Black Hawk Helicopter  157.69     126.15   126.152
# 7                            1911 Ford Town Car   60.54      48.43    48.432
# 8                                P-51-D Mustang   84.48      67.58    67.584
# 9                                P-51-D Mustang   84.48      67.58    67.584
# 10                  1992 Ferrari 360 Spider red  169.34     135.47   135.472
# ...

# %%
#6. Reports those products that have been sold with a markup of 100% or more
#   (i.e.,  the priceEach is at least twice the buyPrice)
run("""SELECT products.productName,products.buyPrice,orderdetails.priceEach
FROM products
INNER JOIN orderdetails ON orderdetails.productCode = products.productCode
GROUP BY products.productCode
HAVING (orderdetails.priceEach-products.buyPrice)/products.buyPrice*100 >= '100'
""")
# Out:
#                                   productName  buyPrice  priceEach
# 0                    1952 Alpine Renault 1300     98.58     214.30
# 1                           2001 Ferrari Enzo     95.59     205.72
# 2                     1970 Plymouth Hemi Cuda     31.92      75.81
# 3                       1926 Ford Fire Engine     24.92      58.34
# 4         1936 Harley Davidson El Knucklehead     24.23      52.70
# 5                      1928 Mercedes-Benz SSK     72.56     167.06
# 6                1999 Indy 500 Monte Carlo SS     56.76     126.72
# 7                 1992 Ferrari 360 Spider red     77.90     165.95
# 8              1948 Porsche Type 356 Roadster     62.16     125.74
# 9                   1957 Corvette Convertible     69.93     139.87
# 10  1938 Cadillac V-16 Presidential Limousine     20.61      44.35
# 11                  1937 Horch 930V Limousine     26.30      55.89
# 12                      1961 Chevrolet Impala     32.33      67.10
# ...

# %%
#7. List the products ordered on a Monday
run("""SELECT products.productName,Count(orderdetails.orderNumber) AS jumlahOrderDiSenin
FROM products
INNER JOIN orderdetails ON orderdetails.productCode = products.productCode
INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
WHERE DAYNAME(orders.orderDate) = 'Monday'
GROUP BY products.productCode
ORDER BY products.productCode ASC
""")
# Out:
#                                     productName  jumlahOrderDiSenin
# 0         1969 Harley Davidson Ultimate Chopper                   6
# 1                      1952 Alpine Renault 1300                   5
# 2                         1996 Moto Guzzi 1100i                   7
# 3          2003 Harley-Davidson Eagle Drag Bike                   7
# 4                           1972 Alfa Romeo GTA                   4
# 5                        1962 LanciaA Delta 16V                   2
# 6                             1968 Ford Mustang                   4
# 7                             2001 Ferrari Enzo                   1
# 8                                1958 Setra Bus                   4
# 9                              2002 Suzuki XREO                   7
# 10                           1969 Corvair Monza                   2
# 11                           1968 Dodge Charger                   4
# 12                      1970 Plymouth Hemi Cuda                   4
# ...

# %%
#8. What is the quantity on hand for products listed on 'On Hold' orders?
data=run("""SELECT products.productCode AS kode, products.productName,
    products.quantityInStock AS stokAwal,
    (SELECT stokAwal-SUM(orderdetails.quantityOrdered)
    FROM orderdetails INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
    WHERE orderdetails.productCode = kode AND orders.`status`='Shipped') AS sisaStok
FROM products
INNER JOIN orderdetails ON orderdetails.productCode = products.productCode
INNER JOIN orders ON orderdetails.orderNumber = orders.orderNumber
WHERE orders.`status` = 'On Hold'
""")
jumlahOnHandStok=(data['stokAwal'].sum()-data['sisaStok'].sum())
print("Jumlah On Hand Stok :",jumlahOnHandStok)
# Out:
# Jumlah On Hand Stok : 37372.0
